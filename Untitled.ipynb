# %% [markdown]
# # libraries used

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from sklearn.neural_network import MLPClassifier
import random

# %% [markdown]
# # load_data

# %%
#load_data 
df = pd.read_csv("creditcard.csv")
#show first 5 raws in data
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# %matplotlib inline
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Scale "Time" and "Amount"
from sklearn.preprocessing import StandardScaler
df[['Scaled_Time','Scaled_Amount']]=StandardScaler().fit_transform(df[['Time','Amount']])
df=df.drop(['Time','Amount'],axis=1)
df.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  Scaled_Time  Scaled_Amount
# 0 -0.189115  0.133558 -0.021053      0    -1.996583       0.244964
# 1  0.125895 -0.008983  0.014724      0    -1.996583      -0.342475
# 2 -0.139097 -0.055353 -0.059752      0    -1.996562       1.160686
# 3 -0.221929  0.062723  0.061458      0    -1.996562       0.140534
# 4  0.502292  0.219422  0.215153      0    -1.996541      -0.073403
#
# [5 rows x 31 columns]

# %%
#prepare data for neural network
X = df.drop(['Class'],axis=1, inplace=False) #  
X = np.array(X).astype(float)
y = df[['Class']]  
y = np.array(y).astype(float)

# %%
#split data (80:20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
print(X_test.shape)
print(X_train.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (56962, 30)
# (227845, 30)
# (56962, 1)
# (227845, 1)

# %% [markdown]
# # create the model and fit data

# %%
clf=MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(28, 30),
              learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
              random_state=0, solver='lbfgs')

# %%
#fit data
clf.fit(X_train,np.ravel(y_train,order='C'))
# Out:
# MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(28, 30),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='lbfgs')

# %%
y_predicted = clf.predict(X_test)

# %%
print(y_predicted)
# Out:
# [1. 0. 0. ... 0. 0. 0.]

# %%
import sklearn
#from sklearn.metrics import roc_curve,roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print('Classification report:\n', classification_report(y_test, y_predicted))
cm=confusion_matrix(y_true = y_test, y_pred = y_predicted)
print('Confusion matrix:\n',np.flip(cm))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.80      0.80      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.90      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion matrix:
#  [[   78    20]
#  [   19 56845]]

# %%
print('accuracy_score : ',sklearn.metrics.accuracy_score(y_test, y_predicted, normalize=True, sample_weight=None))
precision = sklearn.metrics.precision_score(y_test, y_predicted, pos_label=1.0)
print('precision : ',precision)
recall = sklearn.metrics.recall_score(y_test, y_predicted, pos_label=1.0)
print('recall rate : ',recall)
# Out:
# accuracy_score :  0.9993153330290369
# precision :  0.8041237113402062
# recall rate :  0.7959183673469388

# %%
#first we initialize the population with number of solutions(pop_size)
def initialization_pop(pop_size):
    size=[[]]*pop_size
    activation=['identity','logistic','tanh','relu']
    solver=['lbfgs','sgd','adam']
    pop=[[random.choice(activation),random.choice(solver),random.randint(2,100),random.randint(2,100)]for i in range (0,pop_size)]
    return pop

# %%
# just to see the output of (initialization_pop_mlp) function
pop=initialization_pop(6)
print(pop)
# Out:
# [['tanh', 'sgd', 47, 32], ['tanh', 'sgd', 84, 31], ['tanh', 'sgd', 95, 73], ['logistic', 'sgd', 28, 26], ['logistic', 'adam', 46, 90], ['tanh', 'lbfgs', 68, 80]]

# %%
def function_fitness_mlp(pop, x_train,y_train,x_test,y_test):
    fitness=[]
    for w in pop:
        clf=MLPClassifier(activation=w[0],solver=w[1],hidden_layer_sizes=((int(w[2])),(int(w[3]))),learning_rate_init=0.09,alpha=0.0002,max_iter=3000,n_iter_no_change=50,random_state=0)
        clf.fit(x_train,y_train)
        y_predicted = clf.predict(X_test)
        f= sklearn.metrics.precision_score(y_test, y_predicted, pos_label=1.0)
        fitness.append([f,clf,w])
    return fitness

# %%
# just to see the output of (function_fitness_mlp) function
function_fitness_list=function_fitness_mlp(pop, X_train,np.ravel(y_train,order='C'),X_test,y_test)
print(function_fitness_list)
# Out:
# C:\Users\engai\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:699: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [[0.8631578947368421, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(47, 32),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd'), ['tanh', 'sgd', 47, 32]], [0.875, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(84, 31),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd'), ['tanh', 'sgd', 84, 31]], [0.9302325581395349, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(95, 73),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd'), ['tanh', 'sgd', 95, 73]], [0.8837209302325582, MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(28, 26),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd'), ['logistic', 'sgd', 28, 26]], [0.8041237113402062, MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(46, 90),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0), ['logistic', 'adam', 46, 90]], [0.8735632183908046, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(68, 80),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='lbfgs'), ['tanh', 'lbfgs', 68, 80]]]

# %%
# sort solution by thier fitness function
pop_fitness_sort = np.array(list (reversed (sorted(function_fitness_list, key= lambda x: x[0]))))
print(pop_fitness_sort)
Length = len(pop_fitness_sort)
#select parents 
parent_1 = pop_fitness_sort[:,2][: Length//2]
parent_2 = pop_fitness_sort[:,2][Length//2:]
# just to see the output of (select parents ) function
print('parent_1 : ',parent_1)
print('parent_2 : ',parent_2)
# Out:
# [[0.9302325581395349
#   MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(95, 73),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0, solver='sgd')
#   list(['tanh', 'sgd', 95, 73])]
#  [0.8837209302325582
#   MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(28, 26),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0, solver='sgd')
#   list(['logistic', 'sgd', 28, 26])]
#  [0.875
#   MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(84, 31),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0, solver='sgd')
#   list(['tanh', 'sgd', 84, 31])]
#  [0.8735632183908046
#   MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(68, 80),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0, solver='lbfgs')
#   list(['tanh', 'lbfgs', 68, 80])]
#  [0.8631578947368421
#   MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(47, 32),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0, solver='sgd')
#   list(['tanh', 'sgd', 47, 32])]
#  [0.8041237113402062
#   MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(46, 90),
#                 learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#                 random_state=0)
#   list(['logistic', 'adam', 46, 90])]]
# parent_1 :  [list(['tanh', 'sgd', 95, 73]) list(['logistic', 'sgd', 28, 26])
#  list(['tanh', 'sgd', 84, 31])]
# parent_2 :  [list(['tanh', 'lbfgs', 68, 80]) list(['tanh', 'sgd', 47, 32])
#  list(['logistic', 'adam', 46, 90])]
# C:\Users\engai\AppData\Local\Temp\ipykernel_13824\1263194085.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pop_fitness_sort = np.array(list (reversed (sorted(function_fitness_list, key= lambda x: x[0]))))

# %%
# apply crossover on parents to generate childs
def crossover_mlp(parent_1,parent_2):
    child=[parent_1[0],parent_2[1],parent_1[2],parent_2[3]]
    return child
child1=[crossover_mlp (parent_1[i], parent_2[i]) for i in range(0, np.min([len (parent_2), len(parent_1)]))] 
child2= [crossover_mlp (parent_2[i], parent_1[i]) for i in range(0, np.min([len (parent_2), len(parent_1)]))] 
# just to see the output of (crossover_mlp ) function
print('child1 : ',child1)
print("-----------------")
print('child2 : ',child2)
# Out:
# child1 :  [['tanh', 'lbfgs', 95, 80], ['logistic', 'sgd', 28, 32], ['tanh', 'adam', 84, 90]]
# -----------------
# child2 :  [['tanh', 'sgd', 68, 73], ['tanh', 'sgd', 47, 26], ['logistic', 'sgd', 46, 31]]

# %%
# mutation function
def mutation_mlp(child,prob_mut):
    for c in range(0,len(child)):
        if np.random.rand() > prob_mut:
            k=randint(2,3)
            child[c][k]=int(child[c][k])+randint(1,10)
    return child

# just to see the output of (mutation ) function
#apply mutation function on child2
child_2 =mutation_mlp (child2, prob_mut=.7)
print(child_2)
# Out:
# [['tanh', 'sgd', 68, 73], ['tanh', 'sgd', 47, 26], ['logistic', 'sgd', 46, 31]]

# %%
## here we have parents and child as new population
## we have fitnees function for parents . now we will calculate fitness function for childs 
fitness_child_1= function_fitness_mlp (child1,X_train,np.ravel(y_train,order='C'), X_test, y_test) 
print(fitness_child_1)
fitness_child_2 =function_fitness_mlp(child_2, X_train, np.ravel(y_train,order='C'), X_test, y_test)
pop_fitness_sort= np.concatenate((pop_fitness_sort, fitness_child_1, fitness_child_2)) 
sort = np.array(list(reversed (sorted (pop_fitness_sort, key=lambda x: x[0]))))
# Out:
# C:\Users\engai\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[0.8941176470588236, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(95, 80),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='lbfgs'), ['tanh', 'lbfgs', 95, 80]], [0.8941176470588236, MLPClassifier(activation='logistic', alpha=0.0002, hidden_layer_sizes=(28, 32),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd'), ['logistic', 'sgd', 28, 32]], [0.0, MLPClassifier(activation='tanh', alpha=0.0002, hidden_layer_sizes=(84, 90),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0), ['tanh', 'adam', 84, 90]]]
# <__array_function__ internals>:180: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
clf= MLPClassifier(activation='identity', alpha=0.0002, hidden_layer_sizes=(7, 102),
              learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
              random_state=0, solver='sgd')

# %%
clf.fit(X_train,np.ravel(y_train,order='C'))
# Out:
# MLPClassifier(activation='identity', alpha=0.0002, hidden_layer_sizes=(7, 102),
#               learning_rate_init=0.09, max_iter=3000, n_iter_no_change=50,
#               random_state=0, solver='sgd')

# %%
y_predicted = clf.predict(X_test)

# %%
print('Classification report:\n', classification_report(y_test, y_predicted))
cm=confusion_matrix(y_true = y_test, y_pred = y_predicted)
print('Confusion matrix:\n',np.flip(cm))
print('accuracy_score : ',sklearn.metrics.accuracy_score(y_test, y_predicted, normalize=True, sample_weight=None))
precision = sklearn.metrics.precision_score(y_test, y_predicted, pos_label=1.0)
print('precision : ',precision)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.86      0.58      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.79      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion matrix:
#  [[   57    41]
#  [    9 56855]]
# accuracy_score :  0.9991222218320986
# precision :  0.8636363636363636
